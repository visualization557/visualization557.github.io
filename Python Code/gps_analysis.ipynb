# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_car = pd.read_csv('car-assignments.csv', encoding='cp1252')

# %%
df_car
# Out:
#           LastName FirstName  CarID   CurrentEmploymentType  \
# 0          Alcazar     Lucas    1.0  Information Technology
# 1            Azada      Lars    2.0             Engineering
# 2            Balas     Felix    3.0             Engineering
# 3         Barranco    Ingrid    4.0               Executive
# 4             Baza      Isak    5.0  Information Technology
# 5           Bergen    Linnea    6.0  Information Technology
# 6         Borrasca    Isande    7.0             Engineering
# 7          Calixto      Nils    8.0  Information Technology
# 8           Calzas      Axel    9.0             Engineering
# 9   Campo-Corrente       Ada   10.0               Executive
# 10           Cazar    Gustav   11.0             Engineering
# 11        Cocinaro    Hideki   12.0                Security
# 12           Ferro      Inga   13.0                Security
# 13           Dedos   Lidelse   14.0             Engineering
# 14         Bodrogi    Loreto   15.0                Security
# 15            Vann      Isia   16.0                Security
# 16          Flecha      Sven   17.0  Information Technology
# 17          Frente  Birgitta   18.0             Engineering
# 18          Frente      Vira   19.0             Engineering
# 19           Fusil    Stenig   20.0                Security
# 20         Osvaldo    Hennie   21.0                Security
# 21         Herrero     Kanon   22.0                Security
# 22           Lagos     Varja   23.0                Security
# 23            Mies     Minke   24.0                Security
# 24        Nubarron      Adra   25.0             Engineering
# 25            Onda     Marin   26.0             Engineering
# 26          Orilla      Kare   27.0             Engineering
# 27          Orilla      Elsa   28.0             Engineering
# 28            Ovan  Bertrand   29.0              Facilities
# 29         Resumir     Felix   30.0                Security
# 30    Sanjorge Jr.      Sten   31.0               Executive
# 31           Strum     Orhan   32.0               Executive
# 32       Tempestad     Brand   33.0             Engineering
# 33            Vann    Edvard   34.0                Security
# 34      Vasco-Pais    Willem   35.0               Executive
# 35           Hafon    Albina    NaN              Facilities
# 36         Hawelon    Benito    NaN              Facilities
# 37         Hawelon   Claudio    NaN              Facilities
# 38            Mies      Henk    NaN              Facilities
# 39          Morlun   Valeria    NaN              Facilities
# 40          Morlun      Adan    NaN              Facilities
# 41       Morluniau   Cecilia    NaN              Facilities
# 42            Nant     Irene    NaN              Facilities
# 43        Scozzese     Dylan    NaN              Facilities
#
#           CurrentEmploymentTitle
# 0                    IT Helpdesk
# 1                       Engineer
# 2                       Engineer
# 3                        SVP/CFO
# 4                  IT Technician
# 5               IT Group Manager
# 6               Drill Technician
# 7                  IT Technician
# 8               Drill Technician
# 9                        SVP/CIO
# 10          Hydraulic Technician
# 11                  Site Control
# 12                  Site Control
# 13     Engineering Group Manager
# 14                  Site Control
# 15             Perimeter Control
# 16                 IT Technician
# 17                     Geologist
# 18          Hydraulic Technician
# 19              Building Control
# 20             Perimeter Control
# 21                Badging Office
# 22                Badging Office
# 23             Perimeter Control
# 24                     Geologist
# 25            Drill Site Manager
# 26              Drill Technician
# 27              Drill Technician
# 28      Facilities Group Manager
# 29        Security Group Manager
# 30                 President/CEO
# 31                       SVP/COO
# 32              Drill Technician
# 33             Perimeter Control
# 34  Environmental Safety Advisor
# 35                  Truck Driver
# 36                  Truck Driver
# 37                  Truck Driver
# 38                  Truck Driver
# 39                  Truck Driver
# 40                  Truck Driver
# 41                  Truck Driver
# 42                  Truck Driver
# 43                  Truck Driver

# %%
df_gps = pd.read_csv('gps.csv', encoding='cp1252')

# %%
df_gps
# Out:
#                   Timestamp  id        lat       long
# 0       01/06/2014 06:28:01  35  36.076225  24.874689
# 1       01/06/2014 06:28:01  35  36.076220  24.874596
# 2       01/06/2014 06:28:03  35  36.076211  24.874443
# 3       01/06/2014 06:28:05  35  36.076217  24.874253
# 4       01/06/2014 06:28:06  35  36.076214  24.874167
# ...                     ...  ..        ...        ...
# 685164  01/19/2014 20:56:43  30  36.058110  24.902130
# 685165  01/19/2014 20:56:47  30  36.058258  24.901774
# 685166  01/19/2014 20:56:48  30  36.058296  24.901711
# 685167  01/19/2014 20:56:49  30  36.058304  24.901620
# 685168  01/19/2014 20:56:55  30  36.058490  24.901095
#
# [685169 rows x 4 columns]

# %%
filter = (df_gps==35).any()

# %%
filter
# Out:
# Timestamp    False
# id            True
# lat          False
# long         False
# dtype: bool

# %%
sub_df = df_gps.loc[: , filter]

# %%
sub_df
# Out:
#         id
# 0       35
# 1       35
# 2       35
# 3       35
# 4       35
# ...     ..
# 685164  30
# 685165  30
# 685166  30
# 685167  30
# 685168  30
#
# [685169 rows x 1 columns]

# %%
sub_df = df_gps[df_gps['id'] == 34]

# %%
sub_df
# Out:
#                   Timestamp  id        lat       long
# 431     01/06/2014 07:02:01  34  36.067692  24.902492
# 433     01/06/2014 07:02:02  34  36.067701  24.902513
# 436     01/06/2014 07:02:03  34  36.067679  24.902661
# 449     01/06/2014 07:02:08  34  36.067501  24.902768
# 468     01/06/2014 07:02:16  34  36.067223  24.903087
# ...                     ...  ..        ...        ...
# 678805  01/19/2014 15:56:56  34  36.067158  24.903143
# 678806  01/19/2014 15:56:58  34  36.067281  24.902981
# 678807  01/19/2014 15:56:59  34  36.067440  24.902939
# 678808  01/19/2014 15:57:03  34  36.067636  24.902724
# 678809  01/19/2014 15:57:05  34  36.067645  24.902483
#
# [17792 rows x 4 columns]

# %%
sub_df = df_gps[(df_gps['Timestamp'] > '01/06/2014 07:00:00') & (df_gps['Timestamp'] < '01/06/2014 09:00:00')]

# %%
sub_df
# Out:
#                  Timestamp   id        lat       long
# 379    01/06/2014 07:01:01    7  36.084486  24.864238
# 380    01/06/2014 07:01:01   10  36.073338  24.864199
# 381    01/06/2014 07:01:02    7  36.084378  24.864208
# 382    01/06/2014 07:01:04    7  36.084229  24.864223
# 383    01/06/2014 07:01:05    7  36.084181  24.864245
# ...                    ...  ...        ...        ...
# 18338  01/06/2014 08:51:37  107  36.058290  24.885471
# 18339  01/06/2014 08:51:38  107  36.058297  24.885506
# 18340  01/06/2014 08:51:39  107  36.058372  24.885481
# 18341  01/06/2014 08:51:40  107  36.058412  24.885521
# 18342  01/06/2014 08:51:41  107  36.058448  24.885518
#
# [17964 rows x 4 columns]

# %%
morning = []
morning_df = df_gps[(df_gps['Timestamp'] >= '01/06/2014 06:00:00') & (df_gps['Timestamp'] <= '01/06/2014 09:00:00')]

# %%
temp = morning_df[morning_df['id'] == 35]

# %%
temp
# Out:
#                 Timestamp  id        lat       long
# 0     01/06/2014 06:28:01  35  36.076225  24.874689
# 1     01/06/2014 06:28:01  35  36.076220  24.874596
# 2     01/06/2014 06:28:03  35  36.076211  24.874443
# 3     01/06/2014 06:28:05  35  36.076217  24.874253
# 4     01/06/2014 06:28:06  35  36.076214  24.874167
# ...                   ...  ..        ...        ...
# 1840  01/06/2014 07:13:27  35  36.048148  24.879568
# 1841  01/06/2014 07:13:28  35  36.048097  24.879574
# 1842  01/06/2014 07:13:29  35  36.048049  24.879569
# 1844  01/06/2014 07:13:30  35  36.048044  24.879569
# 1846  01/06/2014 07:13:31  35  36.048021  24.879570
#
# [526 rows x 4 columns]

# %%
morning_info = []
for i in range(1, 36):
    morning_info.append(morning_df[morning_df['id'] == i])
for i in range(len(morning_info)):
    try:
        lat_morning = morning_info[i]['lat'].tolist()
        long_morning = morning_info[i]['long'].tolist()
        f = open("morning_" + str(i) + ".kml", "w")
        f.write("<?xml version=\"1.0\" encoding=\"UTF-8\"?>" + "\n" + "<kml xmlns=\"http://earth.google.com/kml/2.1\">" + "\n" + "<Document>" + "\n" + "<Placemark>" + "\n" + "<name>route_" + str(i) + ".kml</name>" + "\n" + "<LineString>" + "\n" + "<tessellate>1</tessellate>" + "\n" + "<coordinates>" + "\n")
        for i in range(len(lat_morning)):
            f.write(str(long_morning[i]) + "," + str(lat_morning[i]))
            f.write("\n")
    #     print(lat, ",", long, ",", "0")
        f.write("</coordinates>" + "\n" + "</LineString>" + "\n" + "</Placemark>" + "\n" + "</Document>" + "\n" + "</kml>")
        f.close()
    except:
        print(i)
# Out:
# 35

# %%
noon = []
noon_df = df_gps[(df_gps['Timestamp'] > '01/11/2014 07:00:00') & (df_gps['Timestamp'] < '01/11/2014 23:00:00')]

# %%
noon_df
# Out:
#                   Timestamp  id        lat       long
# 286837  01/11/2014 11:00:01  15  36.060353  24.905688
# 286838  01/11/2014 11:00:01  15  36.060450  24.905604
# 286839  01/11/2014 11:00:01  16  36.060337  24.905583
# 286840  01/11/2014 11:00:02  15  36.060373  24.905498
# 286841  01/11/2014 11:00:03  15  36.060515  24.905334
# ...                     ...  ..        ...        ...
# 308920  01/11/2014 22:57:53  29  36.076063  24.857617
# 308921  01/11/2014 22:57:54  29  36.076186  24.857572
# 308922  01/11/2014 22:57:55  29  36.076252  24.857598
# 308923  01/11/2014 22:57:57  29  36.076468  24.857571
# 308924  01/11/2014 22:58:00  29  36.076638  24.857613
#
# [22088 rows x 4 columns]

# %%
noon_info = []
for i in range(1, 36):
    noon_info.append(noon_df[noon_df['id'] == i])
for i in range(len(noon_info)):
    try:
        lat_noon = noon_info[i]['lat'].tolist()
        long_noon = noon_info[i]['long'].tolist()
        f = open("noon_" + str(i) + ".kml", "w")
        f.write("<?xml version=\"1.0\" encoding=\"UTF-8\"?>" + "\n" + "<kml xmlns=\"http://earth.google.com/kml/2.1\">" + "\n" + "<Document>" + "\n" + "<Placemark>" + "\n" + "<name>route_" + str(i) + ".kml</name>" + "\n" + "<LineString>" + "\n" + "<tessellate>1</tessellate>" + "\n" + "<coordinates>" + "\n")
        for i in range(len(lat_noon)):
            f.write(str(long_noon[i]) + "," + str(lat_noon[i]))
            f.write("\n")
    #     print(lat, ",", long, ",", "0")
        f.write("</coordinates>" + "\n" + "</LineString>" + "\n" + "</Placemark>" + "\n" + "</Document>" + "\n" + "</kml>")
        f.close()
    except:
        print(i)

# %%
person_info = []
for i in range(1, 36):
    person_info.append(df_gps[df_gps['id'] == i])

# %%
lat = person_info[0]['lat'].tolist()
long = person_info[0]['long'].tolist()

# %%
f = open("demofile3.txt", "w")
for i in range(len(lat)):
    f.write(str(long[i]) + "," + str(lat[i]))
    f.write("\n")
#     print(lat, ",", long, ",", "0")
f.close()

# %%
from dbfread import DBF

# %%
for record in DBF('Geospatial/Kronos_Island.dbf'):
    print(record)
# Out:
# OrderedDict([('Name', 'Kronos')])

# %%
time = person_info[1]['Timestamp'].tolist()

# %%
t = time[0].split(" ")

# %%
t[1] > "07:30:05"
# Out:
# False

# %%
timestamp = []
for i in range(len(person_info)):
    timestamp.append(person_info[i]['Timestamp'].tolist())

# %%
morning = []
for i in range(len(timestamp)):
    for j in range(len(timestamp[i])):
        time = timestamp[i][j].split(" ")

# %%
time
# Out:
# ['01/19/2014', '20:07:17']

# %%
fig, ax = plt.subplots(figsize = (10, 10))
gdf.plot(color='lightgrey',
                      edgecolor = 'black',
                      ax = ax,
                      alpha=.5)
plt.show()
